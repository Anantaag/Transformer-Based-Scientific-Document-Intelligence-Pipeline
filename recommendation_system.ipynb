# %%
from tensorflow.keras import layers
from tensorflow import keras
import tensorflow as tf

from sklearn.model_selection import train_test_split

from ast import literal_eval
# is used for safely evaluating strings containing Python literals or container displays
# (e.g., lists, dictionaries) to their corresponding Python objects.

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
arxiv_data = pd.read_csv("/content/arxiv_data.csv", engine='python')

# %%
arxiv_data.head()
# Out:
#                                         title  \
# 0           Second foot represent apply begin
# 1  Arm whose study more officer notice toward
# 2          Century country allow bag thus man
# 3                    Special reason main fish
# 4           Would official phone time student
#
#                                                                                                                                                                                                                               abstract  \
# 0                                                                                Least describe boy other task example around Culture very far protect seven his operation message Eight sign arrive picture people Now him night help
# 1                                                                                                                                                          Medical up method picture certain herself Break pick value institution live
# 2                                                                 Prevent effect suffer necessary rest fish Off cause field lay as Least beyond drive road Job culture wall thank Consider forward hospital weight away continue leave
# 3  Mouth eye television type either Avoid lay more whose per suddenly tend Staff high often paper Prevent exactly type boy as Operation whether believe eat reveal name mean Six employee office it mother property politics certainly
# 4                                                                                                                                                                           Race since seem food call better Sort girl of artist seven
#
#            domain
# 0           cs.ai
# 1         stat.ml
# 2         stat.ml
# 3  physics.gen-ph
# 4           cs.cl

# %%
arxiv_data.drop(columns = ["domain","abstract"], inplace = True)

# %%
arxiv_data.drop_duplicates(inplace= True)
arxiv_data.reset_index(drop= True,inplace = True)

# %%
pd.set_option('display.max_colwidth', None)
arxiv_data
# Out:
#                                                                      title
# 0                                        Second foot represent apply begin
# 1                               Arm whose study more officer notice toward
# 2                                       Century country allow bag thus man
# 3                                                 Special reason main fish
# 4                                        Would official phone time student
# ..                                                                     ...
# 134  Fact trouble push thing phone someone bag citizen open defense school
# 135                                                Hundred find bit reduce
# 136                                            Newspaper option wide allow
# 137                                                  Official story before
# 138                                     Ball only more list involve dinner
#
# [139 rows x 1 columns]

# %%
# This imports the SentenceTransformer class from the Sentence Transformers library.
from sentence_transformers import SentenceTransformer, util
# we load all-MiniLM-L6-v2, which is a MiniLM model fine tuned on a large dataset of over
# 1 billion training pairs.
#This initializes the 'all-MiniLM-L6-v2' model from Sentence Transformers.
# This model is capable of encoding sentences into fixed-size vectors (embeddings).
model = SentenceTransformer('all-MiniLM-L6-v2')
#Our sentences we like to encode
sentences = arxiv_data['title']
#Sentences are encoded by calling model.encode()
embeddings = model.encode(sentences)

# %%
c = 0
#This loop iterates over pairs of sentences and their corresponding embeddings.
#zip is used to iterate over both lists simultaneously.
for sentence, embedding in zip(sentences, embeddings):
    print("Sentence:", sentence)
    print("Embedding length:", len(embedding)) # list of floats
    print("")
    # Breaks out of the loop after printing information for the first 5 sentences.
    if c >=5:
        break
    c +=1
# Out:
# Sentence: Second foot represent apply begin
# Embedding length: 384
#
# Sentence: Arm whose study more officer notice toward
# Embedding length: 384
#
# Sentence: Century country allow bag thus man
# Embedding length: 384
#
# Sentence: Special reason main fish
# Embedding length: 384
#
# Sentence: Would official phone time student
# Embedding length: 384
#
# Sentence: Through for weight
# Embedding length: 384

# %%
import pickle
# Saving sentences and corresponding embeddings
with open('embeddings.pkl', 'wb') as f:
    pickle.dump(embeddings, f)

with open('sentences.pkl', 'wb') as f:
    pickle.dump(sentences, f)

with open('rec_model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Calculate cosine similarity between first two sentences
sim = cosine_similarity([embeddings[0]], [embeddings[1]])[0][0]
print(f"\nCosine similarity between:\n1️ {sentences[0]}\n2️ {sentences[1]}\n Similarity Score: {sim:.3f}")
# Out:
# Cosine similarity between:
# 1️ Second foot represent apply begin
# 2️ Arm whose study more officer notice toward
#  Similarity Score: 0.252

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('all-MiniLM-L6-v2')

pairs = [
    ("BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding",
     "RoBERTa: A Robustly Optimized BERT Pretraining Approach"),

    ("Deep Residual Learning for Image Recognition",
     "VGGNet: Very Deep Convolutional Networks for Large-Scale Image Recognition"),

    ("Attention Is All You Need",
     "AlphaFold: Predicting Protein Structure with Deep Learning")
]

for p1, p2 in pairs:
    emb1 = model.encode(p1, convert_to_tensor=True)
    emb2 = model.encode(p2, convert_to_tensor=True)
    sim = util.cos_sim(emb1, emb2)
    print(f"\nCosine similarity between:\n1️ {p1}\n2️ {p2}\n Similarity Score: {float(sim):.3f}")
# Out:
# Cosine similarity between:
# 1️ BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding
# 2️ RoBERTa: A Robustly Optimized BERT Pretraining Approach
#  Similarity Score: 0.703
#
# Cosine similarity between:
# 1️ Deep Residual Learning for Image Recognition
# 2️ VGGNet: Very Deep Convolutional Networks for Large-Scale Image Recognition
#  Similarity Score: 0.642
#
# Cosine similarity between:
# 1️ Attention Is All You Need
# 2️ AlphaFold: Predicting Protein Structure with Deep Learning
#  Similarity Score: 0.171
